# %% [markdown]
# # Load Libraries

# %%
import os
import matplotlib.pyplot as plt
import matplotlib as mpl
import contextily as ctx
import descartes as dsc
import pandas as pd
import geopandas as gp
from shapely.geometry import Point
from bokeh.models import ColumnDataSource, HoverTool, BoxZoomTool, ResetTool, SingleIntervalTicker,\
    Slider, Button, Label, CategoricalColorMapper, Legend, Circle, CheckboxButtonGroup, Select, NumeralTickFormatter

# %% [markdown]
# # Import Data

# %%
# Importing the Neighbourhood boundaries data
dr = os.getcwd()
#fdr = 'Final Project'
in_f = 'neighbourhoods.geojson'

target = os.path.join(dr, in_f)

df = gp.read_file(target)

# %%
# Importing the Airbnb listings data with geopoints
dr = os.getcwd()
fdr = ''
in_f = 'listings.geojson'

target = os.path.join(dr, fdr, in_f)

df_airbnb = gp.read_file(target)

# %%
# Importing the Hotels data with geopoints
dr = os.getcwd()
fdr = ''
in_f = 'sorted_hotels.geojson'

target = os.path.join(dr, fdr, in_f)

df_hotels = gp.read_file(target)

# %% [markdown]
# # Check Coordinate Ref System

# %%
# encode the data so as they map onto the Web Mercator scale
df = df.to_crs(epsg=3857)
df_airbnb = df_airbnb.to_crs(epsg=3857)
df_hotels = df_hotels.to_crs(epsg=3857)

# %%
df_airbnb.head()
# Out:
#      id                                              name  host_id  \
# 0  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 1  3831                   Cozy Entire Floor of Brownstone     4869
# 2  5022  Entire Apt: Spacious Studio/Loft by central park     7192
# 3  5099         Large Cozy 1 BR Apartment In Midtown East     7322
# 4  5121                                   BlissArtsSpace!     7356
#
#      host_name neighbourhood_group       neighbourhood        room_type  \
# 0    Elisabeth           Manhattan              Harlem     Private room
# 1  LisaRoxanne            Brooklyn        Clinton Hill  Entire home/apt
# 2        Laura           Manhattan         East Harlem  Entire home/apt
# 3        Chris           Manhattan         Murray Hill  Entire home/apt
# 4        Garon            Brooklyn  Bedford-Stuyvesant     Private room
#
#    price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0    150               3                  0                            NaN
# 1     89               1                279  2019-08-29               4.62
# 2     80              10                  9  2018-11-19               0.10
# 3    200               3                 75  2019-07-21               0.59
# 4     60              45                 49  2017-10-05               0.39
#
#    calculated_host_listings_count  availability_365  \
# 0                               1               365
# 1                               1               192
# 2                               1                 0
# 3                               1                13
# 4                               1                 0
#
#                            geometry
# 0  POINT (-8231174.656 4984212.838)
# 1  POINT (-8233162.822 4966010.228)
# 2  POINT (-8231407.314 4982667.208)
# 3  POINT (-8234859.331 4975193.988)
# 4  POINT (-8232739.808 4966265.665)

# %% [markdown]
# # Filtering and Merging Data

# %%
#remove neighbourhoods outside manhattan
df = df[df.neighbourhood_group == 'Manhattan']
df.head()
# Out:
#         neighbourhood neighbourhood_group  \
# 18  Battery Park City           Manhattan
# 43          Chinatown           Manhattan
# 52            Chelsea           Manhattan
# 53       Civic Center           Manhattan
# 80        East Harlem           Manhattan
#
#                                              geometry
# 18  MULTIPOLYGON (((-8239173.407 4970202.287, -823...
# 43  MULTIPOLYGON (((-8237641.317 4970831.912, -823...
# 52  MULTIPOLYGON (((-8236914.735 4975858.173, -823...
# 53  MULTIPOLYGON (((-8237419.012 4970060.124, -823...
# 80  MULTIPOLYGON (((-8230276.308 4985757.389, -823...

# %%
# Filtering and keeping only entire homes/apt in Manahattan for Airbnb
entire = df_airbnb[df_airbnb.room_type == 'Entire home/apt']
man = entire[entire.neighbourhood_group == 'Manhattan']
man1 = man[man.availability_365 > 100]
man1
# Out:
#              id                                               name    host_id  \
# 7          5222                                      Best Hideaway       7516
# 18         7750                  Huge 2 BR Upper East  Cental Park      17985
# 25         9357                               Midtown Pied-a-terre      30193
# 41        12343                                 BEST BET IN HARLEM      47727
# 48        14287     Cozy 1BD on Central Park West in New York City      56094
# ...         ...                                                ...        ...
# 48349  38551538           Modern Studio APT in the heart of K-TOWN  137669844
# 48354  38553206                Entire Studio in Downtown Manhattan  275978809
# 48357  38553463       (3A) Bright 2 bed in luxury amenity building  278925199
# 48366  38557280  convenient location in nyc entire apt,near subway  112452087
# 48373  38564524                              Central Park Elegance    1567562
#
#       host_name neighbourhood_group    neighbourhood        room_type  price  \
# 7       Marilyn           Manhattan     East Village  Entire home/apt    116
# 18         Sing           Manhattan      East Harlem  Entire home/apt    190
# 25        Tommi           Manhattan   Hell's Kitchen  Entire home/apt    150
# 41         Earl           Manhattan           Harlem  Entire home/apt    150
# 48         Joya           Manhattan  Upper West Side  Entire home/apt    151
# ...         ...                 ...              ...              ...    ...
# 48349   Yeonjoo           Manhattan          Midtown  Entire home/apt    170
# 48354  Longfeng           Manhattan        Chinatown  Entire home/apt    160
# 48357      Saul           Manhattan  Upper East Side  Entire home/apt    220
# 48366    Hannah           Manhattan      East Harlem  Entire home/apt    400
# 48373    Maggie           Manhattan  Upper East Side  Entire home/apt    175
#
#        minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 7                  30                 94  2016-06-15               0.73
# 18                  7                  0                            NaN
# 25                 10                 58  2017-08-13               0.48
# 41                  7                100  2019-07-31               0.85
# 48                  3                 80  2019-09-09               0.68
# ...               ...                ...         ...                ...
# 48349               3                  0                            NaN
# 48354               1                  0                            NaN
# 48357              30                  0                            NaN
# 48366               1                  0                            NaN
# 48373              30                  0                            NaN
#
#        calculated_host_listings_count  availability_365  \
# 7                                   1               347
# 18                                  2               302
# 25                                  1               142
# 41                                  1               317
# 48                                  1               109
# ...                               ...               ...
# 48349                               1               112
# 48354                               1               356
# 48357                              10               263
# 48366                               3               327
# 48373                               1               263
#
#                                geometry
# 7      POINT (-8235359.156 4972251.250)
# 18     POINT (-8231933.855 4982423.106)
# 25     POINT (-8236009.262 4978056.773)
# 41     POINT (-8231495.256 4984614.359)
# 48     POINT (-8234311.640 4980879.230)
# ...                                 ...
# 48349  POINT (-8236196.279 4975074.968)
# 48354  POINT (-8237178.116 4970244.877)
# 48357  POINT (-8233354.292 4977144.059)
# 48366  POINT (-8230677.058 4982574.566)
# 48373  POINT (-8233913.116 4978954.872)
#
# [5342 rows x 15 columns]

# %%
# Grouping dataframe by mean price per neighbourhood
nh = pd.DataFrame(man1.groupby('neighbourhood')['price'].aggregate(np.mean))
nh.head()
# Out:
#                         price
# neighbourhood
# Battery Park City  850.055556
# Chelsea            333.712838
# Chinatown          308.450000
# Civic Center       200.400000
# East Harlem        204.918660

# %%
# Merging neighbourhoods with average airbnb prices
DF = pd.merge(df, nh, on='neighbourhood')
DF.head()
# Out:
#        neighbourhood neighbourhood_group  \
# 0  Battery Park City           Manhattan
# 1          Chinatown           Manhattan
# 2            Chelsea           Manhattan
# 3       Civic Center           Manhattan
# 4        East Harlem           Manhattan
#
#                                             geometry       price
# 0  MULTIPOLYGON (((-8239173.407 4970202.287, -823...  850.055556
# 1  MULTIPOLYGON (((-8237641.317 4970831.912, -823...  308.450000
# 2  MULTIPOLYGON (((-8236914.735 4975858.173, -823...  333.712838
# 3  MULTIPOLYGON (((-8237419.012 4970060.124, -823...  200.400000
# 4  MULTIPOLYGON (((-8230276.308 4985757.389, -823...  204.918660

# %% [markdown]
# ## Number Airbnbs

# %%
#Create copied dataframe for airbnbs
man2 = man1.copy()
man2.loc[:, 'counter'] = 1
man3 = man2.filter(['neighbourhood','counter'], axis=1)
nc = man3.groupby(man3.columns.tolist(),as_index=False).size().reset_index(name="count")
nc = nc.drop('counter', axis=1)

# %%
# Merging Airbnb counts and neighbourhoods
dtf = pd.merge(nc, df, on='neighbourhood')
dtf = dtf.drop('neighbourhood_group', axis=1)
dtf
# Out:
#           neighbourhood  count  \
# 0     Battery Park City     18
# 1               Chelsea    296
# 2             Chinatown     60
# 3          Civic Center      5
# 4           East Harlem    209
# 5          East Village    318
# 6    Financial District    442
# 7     Flatiron District     23
# 8              Gramercy     82
# 9     Greenwich Village     90
# 10               Harlem    388
# 11       Hell's Kitchen    610
# 12               Inwood     26
# 13             Kips Bay    145
# 14         Little Italy     31
# 15      Lower East Side    170
# 16          Marble Hill      1
# 17              Midtown    554
# 18  Morningside Heights      9
# 19          Murray Hill    286
# 20                 NoHo     23
# 21               Nolita     59
# 22     Roosevelt Island      4
# 23                 SoHo     78
# 24      Stuyvesant Town      4
# 25     Theater District    111
# 26              Tribeca     63
# 27          Two Bridges      8
# 28      Upper East Side    527
# 29      Upper West Side    419
# 30   Washington Heights    102
# 31         West Village    181
#
#                                              geometry
# 0   MULTIPOLYGON (((-8239173.407 4970202.287, -823...
# 1   MULTIPOLYGON (((-8236914.735 4975858.173, -823...
# 2   MULTIPOLYGON (((-8237641.317 4970831.912, -823...
# 3   MULTIPOLYGON (((-8237419.012 4970060.124, -823...
# 4   MULTIPOLYGON (((-8230276.308 4985757.389, -823...
# 5   MULTIPOLYGON (((-8236607.493 4973300.426, -823...
# 6   MULTIPOLYGON (((-8239173.407 4970202.287, -823...
# 7   MULTIPOLYGON (((-8235792.300 4974269.053, -823...
# 8   MULTIPOLYGON (((-8235251.955 4973604.975, -823...
# 9   MULTIPOLYGON (((-8236691.650 4972853.241, -823...
# 10  MULTIPOLYGON (((-8230358.462 4987026.630, -823...
# 11  MULTIPOLYGON (((-8236609.719 4976410.716, -823...
# 12  MULTIPOLYGON (((-8228992.572 4991065.824, -822...
# 13  MULTIPOLYGON (((-8234489.973 4974513.833, -823...
# 14  MULTIPOLYGON (((-8237018.150 4971059.274, -823...
# 15  MULTIPOLYGON (((-8234847.420 4970417.004, -823...
# 16  MULTIPOLYGON (((-8227504.675 4993503.099, -822...
# 17  MULTIPOLYGON (((-8233437.893 4976200.864, -823...
# 18  MULTIPOLYGON (((-8233150.243 4983056.313, -823...
# 19  MULTIPOLYGON (((-8234071.078 4975236.747, -823...
# 20  MULTIPOLYGON (((-8236819.000 4971736.545, -823...
# 21  MULTIPOLYGON (((-8236819.000 4971736.545, -823...
# 22  MULTIPOLYGON (((-8231508.615 4978399.834, -823...
# 23  MULTIPOLYGON (((-8237960.247 4972355.104, -823...
# 24  MULTIPOLYGON (((-8234790.091 4973344.352, -823...
# 25  MULTIPOLYGON (((-8235977.313 4976058.613, -823...
# 26  MULTIPOLYGON (((-8237852.267 4971040.180, -823...
# 27  MULTIPOLYGON (((-8236740.408 4969592.969, -823...
# 28  MULTIPOLYGON (((-8231363.009 4980349.663, -823...
# 29  MULTIPOLYGON (((-8233006.752 4982940.580, -823...
# 30  MULTIPOLYGON (((-8228992.572 4991065.824, -822...
# 31  MULTIPOLYGON (((-8238623.043 4974416.419, -823...

# %% [markdown]
# # Finding First Review per Airbnb

# %%
df_reviews = pd.read_csv("reviews.csv")
df_reviews.head()
# Out:
#    listing_id        date
# 0        3831  2014-09-30
# 1        3831  2014-11-02
# 2        3831  2014-11-09
# 3        3831  2014-11-19
# 4        3831  2014-12-06

# %%
# Creating new dataframe with first review of each airbnb

df_reviews = df_reviews.rename(columns={'listing_id': 'id'})
df_reviews['date'] = pd.to_datetime(df_reviews['date'])
df_reviews = pd.DataFrame(df_reviews.groupby('id')['date'].min()) #first review of each listing

# %%
# Creating new dataframe with first review data and location
airbnb = pd.merge(man1, df_reviews, on = 'id')
airbnb['year'] = airbnb['date'].dt.year
airbnb.head()
# Out:
#       id                                            name  host_id  host_name  \
# 0   5222                                   Best Hideaway     7516    Marilyn
# 1   9357                            Midtown Pied-a-terre    30193      Tommi
# 2  12343                              BEST BET IN HARLEM    47727       Earl
# 3  14287  Cozy 1BD on Central Park West in New York City    56094       Joya
# 4  14322             Beautiful Apartment in Manhattan!!!    56284  Francesca
#
#   neighbourhood_group    neighbourhood        room_type  price  \
# 0           Manhattan     East Village  Entire home/apt    116
# 1           Manhattan   Hell's Kitchen  Entire home/apt    150
# 2           Manhattan           Harlem  Entire home/apt    150
# 3           Manhattan  Upper West Side  Entire home/apt    151
# 4           Manhattan         Kips Bay  Entire home/apt    200
#
#    minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0              30                 94  2016-06-15               0.73
# 1              10                 58  2017-08-13               0.48
# 2               7                100  2019-07-31               0.85
# 3               3                 80  2019-09-09               0.68
# 4               7                 19  2019-03-25               0.21
#
#    calculated_host_listings_count  availability_365  \
# 0                               1               347
# 1                               1               142
# 2                               1               317
# 3                               1               109
# 4                               1               316
#
#                            geometry       date  year
# 0  POINT (-8235359.156 4972251.250) 2009-02-23  2009
# 1  POINT (-8236009.262 4978056.773) 2009-10-04  2009
# 2  POINT (-8231495.256 4984614.359) 2010-01-02  2010
# 3  POINT (-8234311.640 4980879.230) 2010-01-01  2010
# 4  POINT (-8235498.305 4974009.734) 2012-04-15  2012

# %%
airbnb.drop(airbnb.iloc[:, 8:14], axis = 1, inplace = True) 
airbnb.head()
# Out:
#       id                                            name  host_id  host_name  \
# 0   5222                                   Best Hideaway     7516    Marilyn
# 1   9357                            Midtown Pied-a-terre    30193      Tommi
# 2  12343                              BEST BET IN HARLEM    47727       Earl
# 3  14287  Cozy 1BD on Central Park West in New York City    56094       Joya
# 4  14322             Beautiful Apartment in Manhattan!!!    56284  Francesca
#
#   neighbourhood_group    neighbourhood        room_type  price  \
# 0           Manhattan     East Village  Entire home/apt    116
# 1           Manhattan   Hell's Kitchen  Entire home/apt    150
# 2           Manhattan           Harlem  Entire home/apt    150
# 3           Manhattan  Upper West Side  Entire home/apt    151
# 4           Manhattan         Kips Bay  Entire home/apt    200
#
#                            geometry       date  year
# 0  POINT (-8235359.156 4972251.250) 2009-02-23  2009
# 1  POINT (-8236009.262 4978056.773) 2009-10-04  2009
# 2  POINT (-8231495.256 4984614.359) 2010-01-02  2010
# 3  POINT (-8234311.640 4980879.230) 2010-01-01  2010
# 4  POINT (-8235498.305 4974009.734) 2012-04-15  2012

# %% [markdown]
# # Get X and Y coordinates of Airbnbs

# %%
#create function to get x and y coordinates of airbnbs

def getPointCoords(row, geom, coord_type):
    """Calculates coordinates ('x' or 'y') of a Point geometry"""
    if coord_type == 'x':
        return row[geom].x
    elif coord_type == 'y':
        return row[geom].y

# %%
airbnb['x'] = airbnb.apply(getPointCoords, geom='geometry', coord_type='x', axis=1)
airbnb['y'] = airbnb.apply(getPointCoords, geom='geometry', coord_type='y', axis=1)
airbnb.head()
# Out:
#       id                                            name  host_id  host_name  \
# 0   5222                                   Best Hideaway     7516    Marilyn
# 1   9357                            Midtown Pied-a-terre    30193      Tommi
# 2  12343                              BEST BET IN HARLEM    47727       Earl
# 3  14287  Cozy 1BD on Central Park West in New York City    56094       Joya
# 4  14322             Beautiful Apartment in Manhattan!!!    56284  Francesca
#
#   neighbourhood_group    neighbourhood        room_type  price  \
# 0           Manhattan     East Village  Entire home/apt    116
# 1           Manhattan   Hell's Kitchen  Entire home/apt    150
# 2           Manhattan           Harlem  Entire home/apt    150
# 3           Manhattan  Upper West Side  Entire home/apt    151
# 4           Manhattan         Kips Bay  Entire home/apt    200
#
#                            geometry       date  year             x  \
# 0  POINT (-8235359.156 4972251.250) 2009-02-23  2009 -8.235359e+06
# 1  POINT (-8236009.262 4978056.773) 2009-10-04  2009 -8.236009e+06
# 2  POINT (-8231495.256 4984614.359) 2010-01-02  2010 -8.231495e+06
# 3  POINT (-8234311.640 4980879.230) 2010-01-01  2010 -8.234312e+06
# 4  POINT (-8235498.305 4974009.734) 2012-04-15  2012 -8.235498e+06
#
#               y
# 0  4.972251e+06
# 1  4.978057e+06
# 2  4.984614e+06
# 3  4.980879e+06
# 4  4.974010e+06

# %%
#Create copied dataframe for airbnbs
a_df = airbnb.drop('geometry', axis = 1).copy()

# %% [markdown]
# # Get x and y coordinates of Hotels

# %%
df_hotels.head()
# Out:
#                                               FIELD1  \
# 0                usa_new york city_inn_new_york_city
# 1                 usa_new york city_casablanca_hotel
# 2                    usa_new york city_library_hotel
# 3            usa_new york city_new_york_palace_hotel
# 4  usa_new york city_the_french_quarters_guest_ap...
#
#                                  doc_id         street             hotel_url  \
# 0                     inn new york city  new york city     266 west 71st st.
# 1                      casablanca hotel  new york city  147 west 43rd street
# 2                         library hotel  new york city    299 madison avenue
# 3                 new york palace hotel  new york city       455 madison ave
# 4  the french quarters guest apartments  new york city    346 w. 46th street
#
#      zip                          geometry
# 0  10023  POINT (-8235925.271 4979765.026)
# 1  10036  POINT (-8236021.696 4976490.058)
# 2  10017  POINT (-8235363.854 4975855.293)
# 3  10022  POINT (-8234858.274 4976739.200)
# 4  10036  POINT (-8236504.077 4977053.409)

# %%
df_hotels['x'] = df_hotels.apply(getPointCoords, geom='geometry', coord_type='x', axis=1)
df_hotels['y'] = df_hotels.apply(getPointCoords, geom='geometry', coord_type='y', axis=1)

# %%
#Create copied dataframe for hotels
h_df = df_hotels.drop('geometry', axis = 1).copy()

# %% [markdown]
# # Create Bokeh Interactive Chart

# %%
import json
from bokeh.io import show
from bokeh.models import (CDSView, ColorBar, ColumnDataSource,
                          CustomJS, CustomJSFilter, 
                          GeoJSONDataSource, HoverTool,
                          LinearColorMapper, Slider)
from bokeh.layouts import column, row, widgetbox
from bokeh.palettes import brewer
from bokeh.plotting import figure
from bokeh.layouts import column, row

# Call column data source for hotels, airbnbs and the shape of manhattan
geosource = GeoJSONDataSource(geojson = dtf.to_json())
asource = ColumnDataSource(a_df)
hsource = ColumnDataSource(h_df)
# Out:
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# <ipython-input-23-c8ef4801921e> in <module>
#      11
#      12 # Call column data source for hotels, airbnbs and the shape of manhattan
# ---> 13 geosource = GeoJSONDataSource(geojson = dtf.to_json())
#      14 asource = ColumnDataSource(a_df)
#      15 hsource = ColumnDataSource(h_df)
#
# //anaconda3/envs/data_vis/lib/python3.7/site-packages/pandas/core/generic.py in to_json(self, path_or_buf, orient, date_format, double_precision, force_ascii, date_unit, default_handler, lines, compression, index)
#    2422             lines=lines,
#    2423             compression=compression,
# -> 2424             index=index,
#    2425         )
#    2426
#
# //anaconda3/envs/data_vis/lib/python3.7/site-packages/pandas/io/json/_json.py in to_json(path_or_buf, obj, orient, date_format, double_precision, force_ascii, date_unit, default_handler, lines, compression, index)
#      76         date_unit=date_unit,
#      77         default_handler=default_handler,
# ---> 78         index=index,
#      79     ).write()
#      80
#
# //anaconda3/envs/data_vis/lib/python3.7/site-packages/pandas/io/json/_json.py in write(self)
#     133             self.date_unit,
#     134             self.date_format == "iso",
# --> 135             self.default_handler,
#     136         )
#     137
#
# //anaconda3/envs/data_vis/lib/python3.7/site-packages/pandas/io/json/_json.py in _write(self, obj, orient, double_precision, ensure_ascii, date_unit, iso_dates, default_handler)
#     232             date_unit,
#     233             iso_dates,
# --> 234             default_handler,
#     235         )
#     236
#
# //anaconda3/envs/data_vis/lib/python3.7/site-packages/pandas/io/json/_json.py in _write(self, obj, orient, double_precision, ensure_ascii, date_unit, iso_dates, default_handler)
#     153             date_unit=date_unit,
#     154             iso_dates=iso_dates,
# --> 155             default_handler=default_handler,
#     156         )
#     157
#
# OverflowError: Maximum recursion level reached

# %% [markdown]
# # Plot data with Airbnbs

# %%
# Define color palettes
palette = brewer['BuGn'][8]
palette = palette[::-1] # reverse order of colors so higher values have darker colors

# Instantiate LinearColorMapper that linearly maps numbers in a range, into a sequence of colors.
color_mapper = LinearColorMapper(palette = palette, low = 1, high = 650)

# Define custom tick labels for color bar.
tick_labels = {'0': '0', '50': '50', '100':'100', '150':'150', '200':'200', '250':'250','300':'300',
               '350':'350', '400':'400', '450': '450', '500': '500', '550': '550', '600': '600', '650': '650'}

# Create color bar.
color_bar = ColorBar(color_mapper = color_mapper, 
                     label_standoff = 8,
                     width = 500, height = 20,
                     border_line_color = None,
                     location = (0,0), 
                     orientation = 'horizontal',
                     major_label_overrides = tick_labels)

# Create figure object.
p = figure(title = 'Airbnb Neighbourhood Prices', 
           plot_height = 600, plot_width = 950, 
           toolbar_location = 'below',
           tools = 'pan, wheel_zoom, box_zoom, reset')
p.xgrid.grid_line_color = None
p.ygrid.grid_line_color = None



# Add patch renderer to figure.
man = p.patches('xs','ys', source = geosource,
                   fill_color = {'field' :'count',
                                 'transform' : color_mapper},
                   line_color = 'gray', 
                   line_width = 0.25, 
                   fill_alpha = 1)


# Make a slider object to toggle the year shown
slider = Slider(start = 2009, end = 2019, 
                value = 1, step = 1, title = 'year')

# This callback triggers the filter when the slider changes
callback = CustomJS(args = dict(source=asource), 
                    code = """source.change.emit();""")

slider.js_on_change('value', callback)

# Creates custom filter that selects the rows of the year based on the value in the slider
custom_filter = CustomJSFilter(args = dict(slider = slider, 
                                           source = asource), 
                               code = '''
var indices = [];
for (var i = 0; i < source.get_length(); i++){
 if (source.data['year'][i] == slider.value){
 indices.push(true);
 } else {
 indices.push(false);
 }
}
return indices;
''')

# Uses custom_filter to determine which set of airbnbs are visible
view = CDSView(source = asource, filters = [custom_filter])

p.circle('x', 'y', source = asource, color = 'blue', 
                  size = 5, alpha = 0.3, view = view)

hotels = p.square('x', 'y', source = hsource, color = 'red', 
                  size = 5, alpha = 0.3)

# Create hover tool for neighbourhood
p.add_tools(HoverTool(renderers = [hotels],
                      tooltips = [('hotel','@doc_id')]))

p.add_tools(HoverTool(renderers = [man],
                      tooltips = [('neighbourhood','@neighbourhood'),
                               ('price','@price')]))

# Specify layout
p.add_layout(color_bar, 'below')


# Make a column layout of widgetbox(slider) and plot, and add it to the current document
layout = column(p, widgetbox(slider))

show(layout)

# %%
# # Define color palettes
# palette = brewer['BuGn'][8]
# palette = palette[::-1] # reverse order of colors so higher values have darker colors

# # Instantiate LinearColorMapper that linearly maps numbers in a range, into a sequence of colors.
# color_mapper = LinearColorMapper(palette = palette, low = 100, high = 900)

# # Define custom tick labels for color bar.
# tick_labels = {'100': '100', '200': '200',
#  '300':'300', '300':'300', '400':'400', '500':'500',
#  '600':'600', '700':'700', '800':'800', '900': '900'}

# # Create color bar.
# color_bar = ColorBar(color_mapper = color_mapper, 
#                      label_standoff = 8,
#                      width = 500, height = 20,
#                      border_line_color = None,
#                      location = (0,0), 
#                      orientation = 'horizontal',
#                      major_label_overrides = tick_labels)

# # Create figure object.
# p1 = figure(title = 'Airbnb Neighbourhood Prices', 
#            plot_height = 600, plot_width = 950, 
#            toolbar_location = 'below',
#            tools = 'pan, wheel_zoom, box_zoom, reset')
# p1.xgrid.grid_line_color = None
# p1.ygrid.grid_line_color = None

# p2 = figure(title = 'Airbnb Neighbourhood Prices', 
#            plot_height = 600, plot_width = 950, 
#            toolbar_location = 'below',
#            tools = 'pan, wheel_zoom, box_zoom, reset')
# p2.xgrid.grid_line_color = None
# p2.ygrid.grid_line_color = None



# # Add patch renderer to figure.
# man = p1.patches('xs','ys', source = geosource,
#                    fill_color = {'field' :'pric',
#                                  'transform' : color_mapper},
#                    line_color = 'gray', 
#                    line_width = 0.25, 
#                    fill_alpha = 1)

# man = p2.patches('xs','ys', source = geosource,
#                    fill_color = {'field' :'price',
#                                  'transform' : color_mapper},
#                    line_color = 'gray', 
#                    line_width = 0.25, 
#                    fill_alpha = 1)


# # Make a slider object to toggle the year shown
# slider = Slider(start = 2009, end = 2019, 
#                 value = 1, step = 1, title = 'year')

# # This callback triggers the filter when the slider changes
# callback = CustomJS(args = dict(source=asource), 
#                     code = """source.change.emit();""")

# slider.js_on_change('value', callback)

# # Creates custom filter that selects the rows of the year based on the value in the slider
# custom_filter = CustomJSFilter(args = dict(slider = slider, 
#                                            source = asource), 
#                                code = '''
# var indices = [];
# for (var i = 0; i < source.get_length(); i++){
#  if (source.data['year'][i] == slider.value){
#  indices.push(true);
#  } else {
#  indices.push(false);
#  }
# }
# return indices;
# ''')

# # Uses custom_filter to determine which set of airbnbs are visible
# view = CDSView(source = asource, filters = [custom_filter])

# p1.circle('x', 'y', source = asource, color = 'blue', 
#                   size = 5, alpha = 0.3, view = view)

# hotels = p1.square('x', 'y', source = hsource, color = 'red', 
#                   size = 5, alpha = 0.3)

# p2.circle('x', 'y', source = asource, color = 'blue', 
#                   size = 5, alpha = 0.3, view = view)

# hotels = p2.square('x', 'y', source = hsource, color = 'red', 
#                   size = 5, alpha = 0.3)

# # Create hover tool for neighbourhood
# p1.add_tools(HoverTool(renderers = [hotels],
#                       tooltips = [('hotel','@doc_id')]))

# p1.add_tools(HoverTool(renderers = [man],
#                       tooltips = [('neighbourhood','@neighbourhood'),
#                                ('price','@price')]))
# p2.add_tools(HoverTool(renderers = [hotels],
#                       tooltips = [('hotel','@doc_id')]))

# p2.add_tools(HoverTool(renderers = [man],
#                       tooltips = [('neighbourhood','@neighbourhood'),
#                                ('price','@price')]))

# # Specify layout
# p1.add_layout(color_bar, 'below')
# p2.add_layout(color_bar, 'below') 

# #show(p)
# l = layout([
#   [bollinger]\,
#   [widgetbox(slider), plot],
#   [p1, p2],
# ], sizing_mode='stretch_both')

# # Make a column layout of widgetbox(slider) and plot, and add it to the current document
# # layout = column(p, widgetbox(slider))

# # show(l)
