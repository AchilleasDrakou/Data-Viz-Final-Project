# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Airbnb

# %%
reviews = pd.read_csv("reviews.csv")
listings = pd.read_csv("listings.csv")

# %%
reviews.head(1)
# Out:
#    listing_id        date
# 0        3831  2014-09-30

# %%
listings.head(1)
# Out:
#      id                                 name  host_id  host_name  \
# 0  3647  THE VILLAGE OF HARLEM....NEW YORK !     4632  Elisabeth
#
#   neighbourhood_group neighbourhood  latitude  longitude     room_type  price  \
# 0           Manhattan        Harlem  40.80902   -73.9419  Private room    150
#
#    minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0               3                  0         NaN                NaN
#
#    calculated_host_listings_count  availability_365
# 0                               1               365

# %% [markdown]
# ## Filters

# %%
entire = listings[listings.room_type == 'Entire home/apt']
man = entire[entire.neighbourhood_group == 'Manhattan']
man = man[man.availability_365 > 100]
man.head(1)
# Out:
#      id           name  host_id host_name neighbourhood_group neighbourhood  \
# 7  5222  Best Hideaway     7516   Marilyn           Manhattan  East Village
#
#    latitude  longitude        room_type  price  minimum_nights  \
# 7  40.72764  -73.97949  Entire home/apt    116              30
#
#    number_of_reviews last_review  reviews_per_month  \
# 7                 94  2016-06-15               0.73
#
#    calculated_host_listings_count  availability_365
# 7                               1               347

# %% [markdown]
# ## Date filters

# %%
reviews = reviews.rename(columns={'listing_id': 'id'}) # match column name for merging
reviews['date'] = pd.to_datetime(reviews['date']) 
reviews = pd.DataFrame(reviews.groupby('id')['date'].min()) #min dates for each listing

# %% [markdown]
# ## Merging listings with reviews

# %%
airbnbs = pd.merge(man, reviews, on = 'id')
airbnbs.head(1)
# Out:
#      id           name  host_id host_name neighbourhood_group neighbourhood  \
# 0  5222  Best Hideaway     7516   Marilyn           Manhattan  East Village
#
#    latitude  longitude        room_type  price  minimum_nights  \
# 0  40.72764  -73.97949  Entire home/apt    116              30
#
#    number_of_reviews last_review  reviews_per_month  \
# 0                 94  2016-06-15               0.73
#
#    calculated_host_listings_count  availability_365       date
# 0                               1               347 2009-02-23

# %%
airbnbs.to_csv(r'Airbnb.csv')

# %% [markdown]
# # Hotels

# %%
#reading the data
hotels = pd.read_csv("new-york-city.csv")
#cleaning the data
hotels.loc[:, "zip"] = hotels["country"].str.split("-").str.get(0)
hotels.reset_index()
# Out:
#                                                  index  \
# 0                  usa_new york city_inn_new_york_city
# 1                   usa_new york city_casablanca_hotel
# 2                      usa_new york city_library_hotel
# 3              usa_new york city_new_york_palace_hotel
# 4    usa_new york city_the_french_quarters_guest_ap...
# ..                                                 ...
# 255                         usa_new york city_the_jane
# 256                      usa_new york city_dylan_hotel
# 257       usa_new york city_the_helmsley_carlton_house
# 258            usa_new york city_amsterdam_court_hotel
# 259            usa_new york city_eurostars_wall_street
#
#                                    doc_id  \
# 0                       inn new york city
# 1                        casablanca hotel
# 2                           library hotel
# 3                   new york palace hotel
# 4    the french quarters guest apartments
# ..                                    ...
# ...

# %%
hotels = hotels[['doc_id','street','hotel_url','zip']]

# %%
hotels.rename(columns={'doc_id':'hotel_name', 'street':'city', 'hotel_url':'address' })
# Out:
#                                                                               hotel_name  \
# usa_new york city_inn_new_york_city                                    inn new york city
# usa_new york city_casablanca_hotel                                      casablanca hotel
# usa_new york city_library_hotel                                            library hotel
# usa_new york city_new_york_palace_hotel                            new york palace hotel
# usa_new york city_the_french_quarters_guest_apa...  the french quarters guest apartments
# ...                                                                                  ...
# usa_new york city_the_jane                                                      the jane
# usa_new york city_dylan_hotel                                                dylan hotel
# usa_new york city_the_helmsley_carlton_house                  the helmsley carlton house
# ...

# %% [markdown]
# # Filter for only Manhattan hotels by zip code

# %%
hotels = hotels[hotels.zip != '']
hotels = hotels[hotels.zip != '07094']
hotels.zip.unique()
# Out:
# array(['10023', '10036', '10017', '10022', '10016', '10019', '10018',
#        '10014', '10024', '10001', '10021', '10012', '10007', '10003',
#        '10002', '10013', '10281', '10128', '10038', '10004', '10011',
#        '10025', '10006', '10005', '10032', '10010'], dtype=object)

# %% [markdown]
# # Using Google Maps API for lat and long data

# %%
from googlemaps import Client as GoogleMaps

# %%
gmaps = GoogleMaps('AIzaSyA_dfooENzsuH6cvimdGDHwNG2Cd-s2gB4')

# %%
hotels['long'] = ""
hotels['lat'] = ""
hotels.head(1)
# Out:
#                                                 doc_id         street  \
# usa_new york city_inn_new_york_city  inn new york city  new york city
#
#                                              hotel_url    zip long lat
# usa_new york city_inn_new_york_city  266 west 71st st.  10023

# %%
for x in range(len(hotels)):
    geocode_result = gmaps.geocode(hotels['hotel_url'][x])
    hotels['lat'][x] = geocode_result[0]['geometry']['location'] ['lat']
    hotels['long'][x] = geocode_result[0]['geometry']['location']['lng']
hotels
# Out:
#                                                                                   doc_id  \
# usa_new york city_inn_new_york_city                                    inn new york city
# usa_new york city_casablanca_hotel                                      casablanca hotel
# usa_new york city_library_hotel                                            library hotel
# usa_new york city_new_york_palace_hotel                            new york palace hotel
# usa_new york city_the_french_quarters_guest_apa...  the french quarters guest apartments
# ...                                                                                  ...
# usa_new york city_hotel_wales                                                hotel wales
# usa_new york city_dylan_hotel                                                dylan hotel
# usa_new york city_the_helmsley_carlton_house                  the helmsley carlton house
# ...

# %%
addresses.to_csv(r'Hotel Addressess.csv')

# %% [markdown]
# # Average price per neighbourhood

# %%
# Mean price per neighberhood
nh = pd.DataFrame(man1.groupby('neighbourhood')['price'].aggregate(np.mean))
nh
# Out:
#                           price
# neighbourhood
# Battery Park City    850.055556
# Chelsea              333.712838
# Chinatown            308.450000
# Civic Center         200.400000
# East Harlem          204.918660
# East Village         259.864780
# Financial District   274.015837
# Flatiron District    530.695652
# Gramercy             404.487805
# Greenwich Village    376.311111
# Harlem               212.365979
# Hell's Kitchen       277.545902
# Inwood               148.000000
# Kips Bay             282.082759
# Little Italy         261.935484
# Lower East Side      320.676471
# Marble Hill          131.000000
# Midtown              287.330325
# Morningside Heights  194.222222
# Murray Hill          247.975524
# NoHo                 413.260870
# Nolita               298.016949
# Roosevelt Island     160.000000
# SoHo                 482.217949
# Stuyvesant Town      222.250000
# Theater District     306.738739
# Tribeca              537.111111
# ...
