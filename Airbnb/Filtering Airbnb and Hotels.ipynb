# %%
import numpy as np
import pandas as pd

# %%
df1 = pd.read_csv("reviews.csv")
df2 = pd.read_csv("reviews 2.csv")
df3 = pd.read_csv("listings.csv")
df4 = pd.read_csv("listings 2.csv")
# Out:
# /opt/anaconda3/envs/geo/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (61,62,94,95) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df1.head(2)
# Out:
#    listing_id        date
# 0        3831  2014-09-30
# 1        3831  2014-11-02

# %%
df2.head(2)
# Out:
#    listing_id        id        date  reviewer_id reviewer_name  \
# 0        3831  20509269  2014-09-30     20417598      Courtney
# 1        3831  22232975  2014-11-02      6050386        Monica
#
#                                             comments
# 0  lisa is a wonderful, kind and thoughtful host....
# 1  The best thing about this place is the locatio...

# %%
df3.head(2)
# Out:
#      id                                 name  host_id    host_name  \
# 0  3647  THE VILLAGE OF HARLEM....NEW YORK !     4632    Elisabeth
# 1  3831      Cozy Entire Floor of Brownstone     4869  LisaRoxanne
#
#   neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0           Manhattan        Harlem  40.80902  -73.94190     Private room
# 1            Brooklyn  Clinton Hill  40.68514  -73.95976  Entire home/apt
#
#    price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0    150               3                  0         NaN                NaN
# 1     89               1                279  2019-08-29               4.62
#
#    calculated_host_listings_count  availability_365
# 0                               1               365
# 1                               1               192

# %% [markdown]
# # Filters
# - we could limit properties only available for more the (100) number of days
# - filter for only entire home/apt

# %%
entire = df3[df3.room_type == 'Entire home/apt']
man = entire[entire.neighbourhood_group == 'Manhattan']
man1 = man[man.availability_365 > 100]
man1
# Out:
#              id                                               name    host_id  \
# 7          5222                                      Best Hideaway       7516
# 18         7750                  Huge 2 BR Upper East  Cental Park      17985
# 25         9357                               Midtown Pied-a-terre      30193
# 41        12343                                 BEST BET IN HARLEM      47727
# 48        14287     Cozy 1BD on Central Park West in New York City      56094
# ...         ...                                                ...        ...
# 48349  38551538           Modern Studio APT in the heart of K-TOWN  137669844
# 48354  38553206                Entire Studio in Downtown Manhattan  275978809
# 48357  38553463       (3A) Bright 2 bed in luxury amenity building  278925199
# 48366  38557280  convenient location in nyc entire apt,near subway  112452087
# 48373  38564524                              Central Park Elegance    1567562
#
# ...

# %% [markdown]
# # Filter for neighbourhoods
# - group by function
# - collapse the data to give the average price per neighberhood

# %%
# Mean price per neighberhood
nh = pd.DataFrame(man1.groupby('neighbourhood')['price'].aggregate(np.mean))
nh
# Out:
#                           price
# neighbourhood
# Battery Park City    850.055556
# Chelsea              333.712838
# Chinatown            308.450000
# Civic Center         200.400000
# East Harlem          204.918660
# East Village         259.864780
# Financial District   274.015837
# Flatiron District    530.695652
# Gramercy             404.487805
# Greenwich Village    376.311111
# Harlem               212.365979
# Hell's Kitchen       277.545902
# Inwood               148.000000
# Kips Bay             282.082759
# Little Italy         261.935484
# Lower East Side      320.676471
# Marble Hill          131.000000
# Midtown              287.330325
# Morningside Heights  194.222222
# Murray Hill          247.975524
# NoHo                 413.260870
# Nolita               298.016949
# Roosevelt Island     160.000000
# SoHo                 482.217949
# Stuyvesant Town      222.250000
# Theater District     306.738739
# Tribeca              537.111111
# ...

# %% [markdown]
# # Date filters

# %% [markdown]
# we need to find the first listing for each location
# - USE df 1 and merge on listing id
# - RENAME DF1 to ID

# %%
df1 = df1.rename(columns={'listing_id': 'id'})
df1['date'] = pd.to_datetime(df1['date'])
df1 = pd.DataFrame(df1.groupby('id')['date'].min()) #min dates for each listing

# %%
DF = pd.merge(man1, df1, on = 'id')
DF
# Out:
#             id                                            name    host_id  \
# 0         5222                                   Best Hideaway       7516
# 1         9357                            Midtown Pied-a-terre      30193
# 2        12343                              BEST BET IN HARLEM      47727
# 3        14287  Cozy 1BD on Central Park West in New York City      56094
# 4        14322             Beautiful Apartment in Manhattan!!!      56284
# ...        ...                                             ...        ...
# 3871  38384178     Luxe Hotel-style Studio close to everything    5079088
# 3872  38397274               Bright & stylish 2BR in Manhattan  291713244
# 3873  38433533     ★SuperHOST★/4Beds/TIME SQUARE/PERFECT FOR U   12864023
# 3874  38472778               Stylish Upper East Side Penthouse  293324549
# 3875  38486383           Sonder | 116 John | Restful 2BR + Gym  219517861
#
#          host_name neighbourhood_group       neighbourhood  latitude  \
# ...

# %% [markdown]
# # Hotels

# %%
hotels = pd.read_csv("hotels/new-york-city.csv")

# %%
hotels
# Out:
#                                                                                   doc_id  \
# usa_new york city_inn_new_york_city                                    inn new york city
# usa_new york city_casablanca_hotel                                      casablanca hotel
# usa_new york city_library_hotel                                            library hotel
# usa_new york city_new_york_palace_hotel                            new york palace hotel
# usa_new york city_the_french_quarters_guest_apa...  the french quarters guest apartments
# ...                                                                                  ...
# usa_new york city_the_jane                                                      the jane
# usa_new york city_dylan_hotel                                                dylan hotel
# usa_new york city_the_helmsley_carlton_house                  the helmsley carlton house
# ...

# %%
addresses = hotels[['doc_id','street','hotel_url','country']]
addresses['long'] = ""
addresses['lat'] = ""
addresses.set_index('doc_id')
addresses.head()
# Out:
# /opt/anaconda3/envs/geo/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /opt/anaconda3/envs/geo/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#                                                                                   doc_id  \
# ...

# %% [markdown]
# # Filter for only Manhattan hotels by zip code

# %%
manhattan = addresses[addresses.country == 10075]
manhattan
# Out:
# Empty DataFrame
# Columns: [doc_id, street, hotel_url, country, long, lat]
# Index: []

# %%
manhattan = addresses[addresses.country == 10026, 10027, 10030, 10037, 10039, 10001, 10011, 10018, 10019, 10020, 10036, 10029, 10035, 10010, 10016, 10017, 10022, 10012, 10013, 10014, 10004, 10005, 10006, 10007, 10038, 10280, 10002, 10003, 10009, 10021, 10028, 10044, 10065, 10075, 10128, 10023, 10024, 10025, 10031, 10032, 10033, 10034, 10040]
manhattan
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-a45b2cdd5e0d> in <module>
# ----> 1 manhattan = addresses[addresses.country == 10026, 10027, 10030, 10037, 10039, 10001, 10011, 10018, 10019, 10020, 10036, 10029, 10035, 10010, 10016, 10017, 10022, 10012, 10013, 10014, 10004, 10005, 10006, 10007, 10038, 10280, 10002, 10003, 10009, 10021, 10028, 10044, 10065, 10075, 10128, 10023, 10024, 10025, 10031, 10032, 10033, 10034, 10040]
#       2 manhattan
#
# /opt/anaconda3/envs/geo/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2993             if self.columns.nlevels > 1:
#    2994                 return self._getitem_multilevel(key)
# -> 2995             indexer = self.columns.get_loc(key)
#    2996             if is_integer(indexer):
#    2997                 indexer = [indexer]
#
# ...

# %%
# Out:
#                                              street             hotel_url  \
# doc_id
# inn new york city                     new york city     266 west 71st st.
# casablanca hotel                      new york city  147 west 43rd street
# library hotel                         new york city    299 madison avenue
# new york palace hotel                 new york city       455 madison ave
# the french quarters guest apartments  new york city    346 w. 46th street
# ...                                             ...                   ...
# the jane                              new york city       113 jane street
# dylan hotel                           new york city   52 east 41st street
# the helmsley carlton house            new york city      680 madison ave.
# amsterdam court hotel                 new york city  226 west 50th street
# eurostars wall street                 new york city          129 front st
#
#                                      long lat
# doc_id
# ...

# %%
from googlemaps import Client as GoogleMaps
import pandas as pd

# %%
gmaps = GoogleMaps('AIzaSyA_dfooENzsuH6cvimdGDHwNG2Cd-s2gB4')

# %%
for x in range(len(addresses)):
    geocode_result = gmaps.geocode(addresses['hotel_url'][x])
    addresses['lat'][x] = geocode_result[0]['geometry']['location'] ['lat']
    addresses['long'][x] = geocode_result[0]['geometry']['location']['lng']
addresses
# Out:
#                                                                                   doc_id  \
# usa_new york city_inn_new_york_city                                    inn new york city
# usa_new york city_casablanca_hotel                                      casablanca hotel
# usa_new york city_library_hotel                                            library hotel
# usa_new york city_new_york_palace_hotel                            new york palace hotel
# usa_new york city_the_french_quarters_guest_apa...  the french quarters guest apartments
# ...                                                                                  ...
# usa_new york city_the_jane                                                      the jane
# usa_new york city_dylan_hotel                                                dylan hotel
# usa_new york city_the_helmsley_carlton_house                  the helmsley carlton house
# ...

# %%
df.to_csv(r'Hotel Addressess.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-0d70d4e430ce> in <module>
# ----> 1 df.to_csv(r'Hotel Addressess.csv')
#
# NameError: name 'df' is not defined

# %%
def plot_coordinates(lat,lon):
    import matplotlib.pyplot as plt
    from mpl_toolkits.basemap import Basemap

    # determine range to print based on min, max lat and lon of the data
    margin = 2 # buffer to add to the range
    lat_min = min(lat) - margin
    lat_max = max(lat) + margin
    lon_min = min(lon) - margin
    lon_max = max(lon) + margin

    # create map using BASEMAP
    m = Basemap(llcrnrlon=lon_min,
                llcrnrlat=lat_min,
                urcrnrlon=lon_max,
                urcrnrlat=lat_max,
                lat_0=(lat_max - lat_min)/2,
                lon_0=(lon_max-lon_min)/2,
                projection='merc',
                resolution = 'h',
                area_thresh=10000.,
                )
    m.drawcoastlines()
    m.drawcountries()
    m.drawstates()
    m.drawmapboundary(fill_color='#46bcec')
    m.fillcontinents(color = 'white',lake_color='#46bcec')
    # convert lat and lon to map projection coordinates
    lons, lats = m(lon, lat)
    # plot points as red dots
    m.scatter(lons, lats, marker = 'o', color='r', zorder=5)
    plt.show()

plot_coordinates(addresses['lat'].values, df['long'].values)

# %%
addresses
