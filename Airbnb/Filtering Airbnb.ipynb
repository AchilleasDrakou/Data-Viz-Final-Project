# %%
import sh
import json
import numpy as np
import pandas as pd

# %%
df1 = pd.read_csv("reviews.csv")
df2 = pd.read_csv("reviews 2.csv")
df3 = pd.read_csv("listings.csv")
df4 = pd.read_csv("listings 2.csv")
# Out:
# /opt/anaconda3/envs/geo/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (61,62,94,95) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df1
# Out:
#          listing_id        date
# 0              3831  2014-09-30
# 1              3831  2014-11-02
# 2              3831  2014-11-09
# 3              3831  2014-11-19
# 4              3831  2014-12-06
# ...             ...         ...
# 1166684    38515988  2019-09-11
# 1166685    38523034  2019-09-11
# 1166686    38536193  2019-09-12
# 1166687    38541362  2019-09-11
# 1166688    38553155  2019-09-12
#
# [1166689 rows x 2 columns]

# %%
df2
# Out:
#          listing_id         id        date  reviewer_id reviewer_name  \
# 0              3831   20509269  2014-09-30     20417598      Courtney
# 1              3831   22232975  2014-11-02      6050386        Monica
# 2              3831   22550887  2014-11-09     15051380       Lynette
# 3              3831   22984049  2014-11-19      7279245        Linnea
# 4              3831   23604706  2014-12-06     16310850      Benjamin
# ...             ...        ...         ...          ...           ...
# 1166684    38515988  527757235  2019-09-11    288981698        Sylvia
# 1166685    38523034  527718324  2019-09-11     84169737        Austin
# 1166686    38536193  528199239  2019-09-12      5176977     Dominique
# 1166687    38541362  527806374  2019-09-11     66094772        Janice
# 1166688    38553155  528025335  2019-09-12    294222140           Ali
#
#                                                   comments
# 0        lisa is a wonderful, kind and thoughtful host....
# ...

# %%
df3
# Out:
#              id                                              name    host_id  \
# 0          3647               THE VILLAGE OF HARLEM....NEW YORK !       4632
# 1          3831                   Cozy Entire Floor of Brownstone       4869
# 2          5022  Entire Apt: Spacious Studio/Loft by central park       7192
# 3          5099         Large Cozy 1 BR Apartment In Midtown East       7322
# 4          5121                                   BlissArtsSpace!       7356
# ...         ...                                               ...        ...
# 48372  38564068                                 Top Floor Delight  207204450
# 48373  38564524                             Central Park Elegance    1567562
# 48374  38566777                              Quiet room available  159902221
# 48375  38567542              Spacious room in Brooklyn brownstone   68905617
# 48376  38568081         Petrose home by JFK, Beach &St John Hosp.  293596932
#
# ...

# %% [markdown]
# # Filters
# - we could limit properties only available for more the (100) number of days
# - filter for only entire home/apt

# %%
entire = df3[df3.room_type == 'Entire home/apt']
man = entire[entire.neighbourhood_group == 'Manhattan']
man1 = man[man.availability_365 > 100]
man1
# Out:
#              id                                               name    host_id  \
# 7          5222                                      Best Hideaway       7516
# 18         7750                  Huge 2 BR Upper East  Cental Park      17985
# 25         9357                               Midtown Pied-a-terre      30193
# 41        12343                                 BEST BET IN HARLEM      47727
# 48        14287     Cozy 1BD on Central Park West in New York City      56094
# ...         ...                                                ...        ...
# 48349  38551538           Modern Studio APT in the heart of K-TOWN  137669844
# 48354  38553206                Entire Studio in Downtown Manhattan  275978809
# 48357  38553463       (3A) Bright 2 bed in luxury amenity building  278925199
# 48366  38557280  convenient location in nyc entire apt,near subway  112452087
# 48373  38564524                              Central Park Elegance    1567562
#
# ...

# %% [markdown]
# # Filter for neighbourhoods
# - group by function
# - collapse the data to give the average price per neighberhood

# %%
nh = man.groupby('neighbourhood').agg(
    av_price = pd.NamedAgg(column = 'price', aggfunc = sum))

# %%
nh
# Out:
#                      av_price
# neighbourhood
# Battery Park City       23664
# Chelsea                225782
# Chinatown               44651
# Civic Center             5648
# East Harlem             97918
# East Village           255668
# Financial District     155728
# Flatiron District       23941
# Gramercy                69334
# Greenwich Village       87128
# Harlem                 187906
# Hell's Kitchen         306698
# Inwood                  11518
# Kips Bay                79895
# Little Italy            23584
# Lower East Side        120445
# Marble Hill               419
# Midtown                270317
# Morningside Heights     20171
# Murray Hill            102595
# NoHo                    22076
# Nolita                  45577
# Roosevelt Island         3989
# SoHo                    77901
# Stuyvesant Town          3561
# Theater District        47698
# Tribeca                 69158
# Two Bridges              4603
# Upper East Side        262931
# ...

# %%
#Filter by Full Six Month Reviews
df3['last_review'] = pd.to_datetime(DF['reviewTime'])

DF.loc[:, "review_year"] = DF["reviewTime"].dt.year # Year column

# %% [markdown]
# we need to find the first listing for each location
# - USE df 1 and merge on listing id
# - RENAME DF1 to ID

# %%
 DF1 = man.rename(columns={'listing_id': 'id'})

# %%
DF = pd.merge(entire, df1, on='asin')
